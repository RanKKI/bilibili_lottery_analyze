# %%
import pandas as pd
prize_users = pd.read_csv("./prize_users.csv")
all_users = pd.read_csv("./all_other_users.csv")

# %%
all_users.describe()
# Out:
#                 uid         level      vip_type    vip_status     time_after
# count  1.263000e+04  12630.000000  12630.000000  12630.000000   12630.000000
# mean   2.243269e+08      3.829295      0.542280      0.236817  250477.374822
# std    1.743140e+08      0.999087      0.726571      0.425146  289099.261204
# min    1.300000e+01      1.000000      0.000000      0.000000     212.000000
# 25%    3.654792e+07      3.000000      0.000000      0.000000   10677.750000
# 50%    2.382717e+08      4.000000      0.000000      0.000000   59733.500000
# 75%    3.855455e+08      5.000000      1.000000      0.000000  583955.000000
# max    6.022326e+08      6.000000      2.000000      1.000000  852418.000000

# %%
prize_users.level[prize_users.level>1].value_counts().plot(kind="pie")

# %%
all_users.level[all_users.level>1].value_counts().plot(kind="pie")

# %%
all_users.level.value_counts()
# Out:
# 4    4412
# 5    3522
# 3    3119
# 2    1422
# 6     150
# 1       5
# Name: level, dtype: int64

# %%
prize_users.vip_status.value_counts()
# Out:
# 0    17
# 1    16
# Name: vip_status, dtype: int64

# %%
vip_st = pd.DataFrame({
    "prize users":prize_users.vip_type[prize_users.vip_status == 1].value_counts(),
    "all users":all_users.vip_type[all_users.vip_status == 1].value_counts()
})
vip_st.plot(kind="bar",secondary_y="all users")

# %%
all_users["time"] = all_users["time_after"] / 60 / 60
prize_users["time"] = prize_users["time_after"] / 60 / 60

# %%
t = 5*60*60
pd.DataFrame({
    "prize": prize_users.time_after[prize_users.time_after < t] / 60 / 60,
    "all": all_users.time_after[all_users.time_after  < t] / 60 / 60
}).plot(kind="hist", secondary_y="all", bins=200, alpha=0.5)

# %%
prize_users[prize_users.time_after < 2*60*60]
# Out:
#           uid  level  vip_type  vip_status  time_after      time
# 2    94078703      5         2           1        5347  1.485278
# 6    33613766      5         2           1         292  0.081111
# 7    49628423      5         1           0        5783  1.606389
# 15    8196934      5         2           1        1296  0.360000
# 16    8306171      5         0           0        3331  0.925278
# 21   37125593      5         1           1         351  0.097500
# 23   73275305      5         0           0         925  0.256944
# 24  208279268      5         2           1        2906  0.807222
# 26  294139644      4         0           0        2682  0.745000
# 29  393686726      4         1           0         281  0.078056
# 30  393724466      3         0           0         569  0.158056
# 31  471003008      4         1           1        6909  1.919167

# %%
prize_users["time"].plot(kind="hist", bins=200)
